# %%
print('manish')
# Out:
# manish

# %% [markdown]
# # point
# - efn
# - fn
# - nv

# %% [markdown]
# ![mountains-sun-sunrise-morning-100077.jpg](attachment:mountains-sun-sunrise-morning-100077.jpg)

# %%
a = "10"

# %%
type(a)
# Out:
# str

# %% [markdown]
# Ascii codes of chars, numbers and special chars

# %%
s = 'A_ abcd1234!@#$'

# %%
a = 'A'
print(ord(a))
# Out:
# 65

# %%
for i in s:
    print(ord(i))
# Out:
# 65
# 95
# 32
# 97
# 98
# 99
# 100
# 49
# 50
# 51
# 52
# 33
# 64
# 35
# 36

# %%
a = 'a'
print(ord(a))
# Out:
# 97

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import math

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     comb(n, k, /)
# ...

# %%
type?

# %%
math.factorial(5)
# Out:
# 120

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = str(int(float(a)))

# %%
a
# Out:
# '10'

# %% [markdown]
# rules to define variable_name:
# - we should start with a char or string.
# - we can start with char and then we can have a no.
# - I cannot start with a no. it will show me error
# - I cannot start with special chars like @,!,%, &,*,(,),-,+
# - but i can use _ underscore to define the variable_name
# - plus I cannot use the keywords

# %% [markdown]
# # Operation

# %%
a = 10
b = 20
c = 30

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
10-20
# Out:
# -10

# %%
30-40
# Out:
# -10
